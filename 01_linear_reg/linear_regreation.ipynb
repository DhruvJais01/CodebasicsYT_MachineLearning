# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  560000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([627739.7260274])

# %%
reg.coef_
# Out:
# array([136.98630137])

# %%
reg.intercept_
# Out:
# 175684.9315068493

# %%
# y = m*x+b
136.98630137*3300+175684.9315068493
# Out:
# 627739.7260278494

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[["area"]]),color='blue')

# %%
d = pd.read_csv("areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['price'] = p

# %%
d
# Out:
#     area         price
# 0   1000  3.126712e+05
# 1   1500  3.811644e+05
# 2   2300  4.907534e+05
# 3   3540  6.606164e+05
# 4   4120  7.400685e+05
# 5   4560  8.003425e+05
# 6   5490  9.277397e+05
# 7   3460  6.496575e+05
# 8   4750  8.263699e+05
# 9   2300  4.907534e+05
# 10  9000  1.408562e+06
# 11  8600  1.353767e+06
# 12  7100  1.148288e+06

# %%
d.to_csv("prediction.csv", index=False)
