# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example of housing price predication

# %% [markdown]
# ![image.png](attachment:image.png)
# Selection 1

# %% [markdown]
# ![image.png](attachment:image.png)
# Selection 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Bias: train error__
#
# __Variance: test error__
#
# Overfit ~ Variance(^)
#
# Underfit ~ Bias(^)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# white square are predicated values

# %% [markdown]
# Balanced Model:
# ![image.png](attachment:image.png)
